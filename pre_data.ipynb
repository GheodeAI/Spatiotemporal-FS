# %%
import xarray as xr
import numpy as np

# %%
data = xr.open_dataset(f'./z500/data_z500_{2011}_daily.nc')

# %%
data
# Out:
# <xarray.Dataset>
# Dimensions:    (longitude: 720, latitude: 361, time: 365)
# Coordinates:
#   * longitude  (longitude) float32 -180.0 -179.5 -179.0 ... 178.5 179.0 179.5
#   * latitude   (latitude) float32 90.0 89.5 89.0 88.5 ... -89.0 -89.5 -90.0
#   * time       (time) datetime64[ns] 2011-01-01 2011-01-02 ... 2011-12-31
# Data variables:
#     z          (time, latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2023-08-29 10:48:29 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...

# %%
for y in np.arange(2012, 2023):
    print(y)
    data2 = xr.open_dataset(f'./sst/data_sst_{y}_daily.nc')
    # data2 = data2.isel(latitude=slice(None,None,2),longitude=slice(None,None,2))
    data = xr.concat([data,data2 ], dim='time')
    data.to_netcdf('./sst/data_sst_2011_2022.nc')
# Out:
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2018
# 2019
# 2020
# 2021
# 2022

# %%
plt.plot(data.time,data.z[:,240,50])
